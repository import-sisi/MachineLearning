# %%
import numpy as np

X11 = np.random.normal(loc=0, scale=2, size=100)
X12 = np.random.normal(loc=-1, scale=2, size=100)
X1 = np.stack([X11, X12], axis=1)
print(X1.shape)

X21 = np.random.normal(loc=5, scale=1.5, size=100)
X22 = np.random.normal(loc=2, scale=1, size=100)
X2 = np.stack([X21, X22], axis=1)

X31 = np.random.normal(loc=-3, scale=2, size=100)
X32 = np.random.normal(loc=7, scale=2, size=100)
X3 = np.stack([X31, X32], axis=1)

X = np.concatenate([X1, X2, X3])
y = np.array([0]*100+[1]*100+[2]*100)
print(y.shape)
# Out:
# (100, 2)
# (300,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.scatter(X1[:, 0], X1[:, 1], c='red')
plt.scatter(X2[:, 0], X2[:, 1], c='blue')
plt.scatter(X3[:, 0], X3[:, 1], c='green')
plt.show()
